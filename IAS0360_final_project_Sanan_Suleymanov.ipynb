# %%
#The related data of project such as exported models, training and testing results as well as scripts can be founded inside of YOLOv5 folder
#inside of yolov5-->data folder there is custom.yaml file where it is possible to give directories of train, test and validation datasets
#exported models of YOLOv5n are inside of yolov5-->runs-->train-->exp3-->weights directory

#--------------------------------------------------------------------------------#
# The yolov5 and Images folder can be founded using the following link:
# https://drive.google.com/drive/folders/1dGUswVPRBEX4FpJV9X-MtIkeGcS2Cz69?usp=sharing

# %%
#!pip install tensorflow==2.5.0  for exporting model in uint8 type it is needed to use tensorflow 2.5.0
# Out:
# ...
#      |████████████████████████████████| 454.3 MB 18 kB/s
# ...
#      |████████████████████████████████| 1.2 MB 41.0 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 43.3 MB/s
# ...
#      |████████████████████████████████| 462 kB 45.8 MB/s
# ...
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.6.0
#     Uninstalling tensorflow-2.6.0:
#       Successfully uninstalled tensorflow-2.6.0
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Project_ML/yolov5
# Out:
# /content/drive/MyDrive/Project_ML/yolov5

# %%
# !git clone https://github.com/ultralytics/yolov5  # clones the GitHub YOLOv5 repository
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 10191, done.
# remote: Total 10191 (delta 0), reused 0 (delta 0), pack-reused 10191
# Receiving objects: 100% (10191/10191), 10.41 MiB | 8.36 MiB/s, done.
# Resolving deltas: 100% (7067/7067), done.
# /content/drive/My Drive/Project_ML/yolov5
#      |████████████████████████████████| 596 kB 5.2 MB/s

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data custom.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2021-12-12 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/Project_ML/Images/test --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp2/weights/best.pt --img 640
# Out:
# detect: weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/Project_ML/Images/test, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients
# image 1/21 /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0002_15_18.png: 480x640 3 Humans, 1 Non-human, Done. (0.032s)
# image 2/21 /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0015_15_18.png: 480x640 4 Humans, 1 Non-human, Done. (0.030s)
# ...

# %%
# !python val.py --data custom.yaml --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp2/weights/best.pt --img 640
# Out:
# val: data=/content/drive/MyDrive/Project_ML/yolov5/data/custom.yaml, weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp2/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients
# val: Scanning '/content/drive/MyDrive/Project_ML/Images/validation.cache' images and labels... 17 found, 0 missing, 0 empty, 0 corrupted: 100% 17/17 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                  all         17         63      0.955      0.978      0.971      0.709
# ...

# %%
# !python export.py --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp2/weights/best.pt --include torchscript tflite --data custom.yaml
# Out:
# export: data=custom.yaml, weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=14, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'tflite']
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients
#
# PyTorch: starting from /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp2/weights/best.pt (14.4 MB)
#
# TorchScript: starting export with torch 1.10.0+cu111...
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data custom.yaml --weights yolov5n.pt --cache
# Out:
# train: weights=yolov5n.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/ultralytics/yolov5
#    8f35436..19c56e6  master     -> origin/master
# ...

# %%
# !python export.py --int8 --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt --include torchscript tflite --data /content/drive/MyDrive/Project_ML/yolov5/data/custom.yaml
# Out:
# export: data=/content/drive/MyDrive/Project_ML/yolov5/data/custom.yaml, weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=True, dynamic=False, simplify=False, opset=14, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'tflite']
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 1761871 parameters, 0 gradients
#
# PyTorch: starting from /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt (3.9 MB)
#
# TorchScript: starting export with torch 1.10.0+cu111...
# ...

# %%
# !python val.py --data custom.yaml --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt --img 640
# Out:
# val: data=/content/drive/MyDrive/Project_ML/yolov5/data/custom.yaml, weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1761871 parameters, 0 gradients
# val: Scanning '/content/drive/MyDrive/Project_ML/Images/validation.cache' images and labels... 17 found, 0 missing, 0 empty, 0 corrupted: 100% 17/17 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.21s/it]
#                  all         17         63      0.926      0.954      0.965       0.71
# ...

# %%
# !python val.py --data custom.yaml --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/last.pt --img 640
# Out:
# val: data=/content/drive/MyDrive/Project_ML/yolov5/data/custom.yaml, weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/last.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1761871 parameters, 0 gradients
# val: Scanning '/content/drive/MyDrive/Project_ML/Images/validation.cache' images and labels... 17 found, 0 missing, 0 empty, 0 corrupted: 100% 17/17 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 1/1 [00:01<00:00,  1.17s/it]
#                  all         17         63        0.9      0.978      0.966      0.681
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/Project_ML/Images/test --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt --img 640
# Out:
# detect: weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Project_ML/Images/test, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1761871 parameters, 0 gradients
# image 1/21 /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0002_15_18.png: 480x640 3 Humans, 1 Non-human, Done. (0.021s)
# image 2/21 /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0015_15_18.png: 480x640 4 Humans, 1 Non-human, Done. (0.020s)
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/Project_ML/Images/test --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/last.pt --img 640
# Out:
# detect: weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/last.pt'], source=/content/drive/MyDrive/Project_ML/Images/test, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-139-g8f35436 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1761871 parameters, 0 gradients
# image 1/21 /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0002_15_18.png: 480x640 3 Humans, 1 Non-human, Done. (0.021s)
# image 2/21 /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0015_15_18.png: 480x640 4 Humans, 1 Non-human, Done. (0.020s)
# ...

# %%
# !python detect.py --source /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0023_15_19.png --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/last.pt --img 640
# Out:
# ...
# detect: weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/last.pt'], source=/content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0023_15_19.png, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
#
# requirements: 1 package updated per /content/drive/MyDrive/Project_ML/yolov5/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %%
import matplotlib.pyplot as plt
detect_img = plt.imread('runs/detect/exp8/fig_20210507_1605_3078_0023_15_19.png')
plt.imshow(detect_img)

# %%
# !python detect.py --source /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0023_15_19.png --weights /content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt --img 640
# Out:
# detect: weights=['/content/drive/MyDrive/Project_ML/yolov5/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0023_15_19.png, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-12-12 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1761871 parameters, 0 gradients
# image 1/1 /content/drive/MyDrive/Project_ML/Images/test/fig_20210507_1605_3078_0023_15_19.png: 480x640 3 Humans, 1 Non-human, Done. (0.022s)
# Speed: 0.5ms pre-process, 21.7ms inference, 1.7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp7

# %%
detect_img = plt.imread('runs/detect/exp7/fig_20210507_1605_3078_0023_15_19.png')
plt.imshow(detect_img)
